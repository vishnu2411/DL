# %%
import random

# %%
W=[0]*12

# %%
for i in range(12):
    W[i]=random.random()

# %%
W
# Out:
# [0.8876819907260469,
#  0.5042870700859206,
#  0.9654308725320161,
#  0.9517192337823142,
#  0.7132469932878515,
#  0.01060364410841419,
#  0.37043893958531704,
#  0.8418406752889952,
#  0.3270698967252782,
#  0.42239144780300464,
#  0.2406901866278791,
#  0.2383663109945825]

# %%
import pandas as pd

# %%
ds=pd.read_csv('iris.csv')

# %%
ds
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import numpy as np

# %%
X=ds.to_numpy()
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'setosa'],
#        [4.6, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.6, 1.4, 0.2, 'setosa'],
#        [5.4, 3.9, 1.7, 0.4, 'setosa'],
#        [4.6, 3.4, 1.4, 0.3, 'setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.1, 'setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'setosa'],
#        [4.8, 3.4, 1.6, 0.2, 'setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'setosa'],
#        [5.7, 4.4, 1.5, 0.4, 'setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'setosa'],
#        [5.1, 3.5, 1.4, 0.3, 'setosa'],
#        [5.7, 3.8, 1.7, 0.3, 'setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'setosa'],
# ...

# %%
X[0][:4]
# Out:
# array([5.1, 3.5, 1.4, 0.2], dtype=object)

# %%
np.shape(X)
# Out:
# (150, 5)

# %%
np.shape(W)
# Out:
# (12,)

# %%
y1=X[0][0]*W[0]+X[0][1]*W[3]+X[0][2]*W[6]+X[0][3]*W[9]

# %%
y1
# Out:
# 8.461288275920982

# %%
Y1=[0]*50
for i in range(50):
    Y1[i]=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
Y1
# Out:
# [8.461288275920982,
#  7.807892260884617,
#  7.783655815537339,
#  7.673803481003565,
#  8.46769200022661,
#  9.30389053808792,
#  7.964514501960028,
#  8.31439204742868,
#  7.268879342143363,
#  7.897868933441079,
#  8.954980613853792,
#  8.173899543242001,
#  7.676884917031711,
#  7.121912239793093,
#  9.484437498403308,
#  9.971966964279828,
#  9.155714962253793,
#  8.503527420701284,
#  9.432784067147203,
#  8.82608708479451,
#  8.743552631636161,
#  8.773154306196579,
#  7.964443628102064,
#  8.508793545381018,
#  8.285031225117596,
#  7.970748247874285,
#  8.435914230947812,
#  8.58710036895212,
#  8.454884551615356,
#  7.894787497412934,
#  7.888383773107307,
#  8.7539431332797,
#  9.115892764441208,
#  9.482564535859021,
#  7.897868933441079,
#  8.012916518796622,
#  8.779317178252871,
#  7.897868933441079,
#  7.327007371563063,
#  8.403160246501283,
#  8.377715327670149,
#  6.791811251768347,
#  7.517351218319527,
#  8.615564443886644,
#  9.016501805408936,
# ...

# %%
print(min(Y1),max(Y1))
# Out:
# 6.791811251768347 9.971966964279828

# %%
Y2=[0]*50
k=0
for i in range(50,100):
    Y2[k]=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
    k+=1
Y2
# Out:
# [10.106017304259877,
#  9.659145945813313,
#  10.176701051643088,
#  8.094306913806845,
#  9.508459923035664,
#  8.972708162112452,
#  9.872479091854093,
#  7.201563842393418,
#  9.582075292047465,
#  8.168204541230098,
#  7.135061887144668,
#  9.011800809526084,
#  8.202918693532656,
#  9.438184843196193,
#  8.235947546672548,
#  9.630854281318618,
#  9.113066891087007,
#  8.542868843688296,
#  8.845041538508278,
#  8.155062914618533,
#  9.731761669345415,
#  8.753502652502323,
#  9.446180613618823,
#  9.318722106541832,
#  9.228665675443583,
#  9.50910087498124,
#  9.80404516045645,
#  10.136841043151593,
#  9.243457019792588,
#  7.916011032177524,
#  7.949125440752255,
#  7.840872354560568,
#  8.422638745956075,
#  9.629981044971204,
#  9.012209477069822,
#  9.624149535099303,
#  9.907475502568104,
#  8.83447283999118,
#  8.728192583645832,
#  8.236956312464416,
#  8.620948263246012,
#  9.425325474996079,
#  8.43549811415619,
#  7.180667850073225,
#  8.598402553188377,
# ...

# %%
print(min(Y2),max(Y2))
# Out:
# 7.135061887144668 10.176701051643088

# %%
Y3=[0]*50
k=0
for i in range(100,150):
    Y3[k]=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
    k+=1
Y3
# Out:
# [8.675541680347592,
#  7.749081363967037,
#  9.31665177107032,
#  8.37361584631791,
#  8.728522888978041,
#  10.028316135044024,
#  6.634157649632457,
#  9.56799564655762,
#  8.820960717032404,
#  9.580317548531461,
#  8.454021427893114,
#  8.393753866831302,
#  8.896194550620605,
#  7.641547189319084,
#  7.86932488387517,
#  8.494402213283342,
#  8.535055395562626,
#  10.189885758355942,
#  10.266411995870358,
#  7.808812202348873,
#  9.107945608239461,
#  7.515478205625877,
#  10.131608852048611,
#  8.142546189788531,
#  8.868246535944982,
#  9.376512683519358,
#  8.014356477273642,
#  7.952641108514652,
#  8.540608462458643,
#  9.261304713153704,
#  9.62190102115438,
#  10.237177701645846,
#  8.564445093558101,
#  8.137510640246052,
#  8.082002054181148,
#  10.008997536133503,
#  8.521937454968866,
#  8.439572672720265,
#  7.8233910315889235,
#  8.96109101261212,
#  8.904928710749147,
#  8.910643305793453,
#  7.749081363967037,
#  9.076816500331315,
#  8.963593060342816,
# ...

# %%
print(min(Y3),max(Y3))
# Out:
# 6.634157649632457 10.266411995870358

# %%
for i in range(12):
    W[i]=round(random.random(),2)
W
# Out:
# [0.68, 0.46, 0.77, 0.73, 0.99, 0.38, 0.51, 0.26, 0.74, 0.73, 0.3, 0.73]

# %%
Y1=[0]*50
for i in range(50):
    Y1[i]=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
Y1
# Out:
# [6.883,
#  6.382000000000001,
#  6.341,
#  6.302,
#  6.888000000000001,
#  7.678,
#  6.543,
#  6.792999999999999,
#  5.969,
#  6.433000000000001,
#  7.284000000000001,
#  6.708,
#  6.241000000000001,
#  5.748,
#  7.622,
#  8.145000000000001,
#  7.474,
#  6.956,
#  7.736000000000001,
#  7.226,
#  7.167,
#  7.226,
#  6.412,
#  7.109,
#  6.861000000000001,
#  6.552,
#  6.989999999999999,
#  7.002,
#  6.878000000000001,
#  6.494,
#  6.489,
#  7.210999999999999,
#  7.367,
#  7.6659999999999995,
#  6.433000000000001,
#  6.494000000000001,
#  7.104,
#  6.433000000000001,
#  5.9910000000000005,
#  6.860999999999999,
#  6.837000000000001,
#  5.621,
#  6.1370000000000005,
#  7.209,
#  7.503,
#  6.387000000000001,
#  7.204,
#  6.324000000000001,
#  7.215999999999999,
#  6.669]

# %%
print(min(Y1),max(Y1))
# Out:
# 5.621 8.145000000000001

# %%
Y2=[0]*50
k=0
for i in range(50,100):
    Y2[k]=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
    k+=1
Y2
# Out:
# [8.030000000000001,
#  7.732,
#  7.9670000000000005,
#  6.237,
#  7.408,
#  6.954,
#  7.867000000000001,
#  5.788,
#  7.492999999999999,
#  6.4990000000000006,
#  5.49,
#  7.226,
#  6.2780000000000005,
#  7.319,
#  6.773,
#  7.715,
#  7.1659999999999995,
#  6.707,
#  6.65,
#  6.3950000000000005,
#  7.670000000000001,
#  7.007999999999999,
#  7.097,
#  7.16,
#  7.3229999999999995,
#  7.57,
#  7.5680000000000005,
#  7.861999999999999,
#  7.251,
#  6.406,
#  6.224,
#  6.168,
#  6.715000000000001,
#  7.238999999999999,
#  7.074000000000001,
#  7.776,
#  7.823,
#  6.709,
#  7.001999999999999,
#  6.4350000000000005,
#  6.6080000000000005,
#  7.3919999999999995,
#  6.642,
#  5.734999999999999,
#  6.731000000000001,
#  7.044000000000001,
#  6.9750000000000005,
#  7.231000000000001,
#  5.931,
#  6.85]

# %%
print(min(Y2),max(Y2))
# Out:
# 5.49 8.030000000000001

# %%
Y3=[0]*50
k=0
for i in range(100,150):
    Y3[k]=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
    k+=1
Y3
# Out:
# [12.37,
#  10.653,
#  12.505999999999998,
#  11.411,
#  12.043,
#  13.408999999999997,
#  9.294,
#  12.698999999999998,
#  11.715,
#  13.251,
#  11.454999999999998,
#  11.263000000000002,
#  11.979,
#  10.499000000000002,
#  11.056000000000001,
#  11.745000000000001,
#  11.529,
#  13.937,
#  13.702,
#  10.251000000000001,
#  12.426,
#  10.462,
#  13.411000000000001,
#  10.817,
#  12.164,
#  12.514,
#  10.704,
#  10.777000000000001,
#  11.669,
#  12.144,
#  12.663,
#  13.722999999999999,
#  11.742,
#  10.784,
#  10.851,
#  13.262,
#  12.039,
#  11.490000000000002,
#  10.626,
#  12.02,
#  12.233000000000002,
#  11.944,
#  10.653,
#  12.497000000000002,
#  12.456,
#  11.826000000000002,
#  10.888000000000002,
#  11.453,
#  11.741,
#  10.770999999999999]

# %%
print(min(Y3),max(Y3))
# Out:
# 9.294 13.937

# %%
for i in range(12):
    W[i]=round(random.random(),2)
W
# Out:
# [0.87, 0.68, 0.46, 0.03, 0.08, 0.7, 0.65, 0.3, 0.38, 0.9, 0.99, 0.17]

# %%
Y1=[0]*50
for i in range(50):
    Y1[i]=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
Y1
# Out:
# [5.632,
#  5.443,
#  5.21,
#  5.25,
#  5.547999999999999,
#  6.28,
#  5.284000000000001,
#  5.606999999999999,
#  5.005,
#  5.420999999999999,
#  5.964,
#  5.498,
#  5.266,
#  4.635999999999999,
#  6.126,
#  6.426000000000001,
#  6.0200000000000005,
#  5.7219999999999995,
#  6.448,
#  5.795999999999999,
#  6.085000000000001,
#  5.883,
#  4.9399999999999995,
#  6.091,
#  5.693,
#  5.659999999999999,
#  5.852,
#  5.784000000000001,
#  5.716,
#  5.405,
#  5.489,
#  6.135000000000001,
#  5.712,
#  6.001,
#  5.420999999999999,
#  5.406,
#  5.915,
#  5.420999999999999,
#  4.943,
#  5.693999999999999,
#  5.57,
#  5.099,
#  4.949,
#  6.035,
#  6.146,
#  5.446,
#  5.770999999999999,
#  5.188,
#  5.876999999999999,
#  5.539]

# %%
print(min(Y1),max(Y1))
# Out:
# 4.635999999999999 6.448

# %%
Y2=[0]*50
k=0
for i in range(50,100):
    Y2[k]=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
    k+=1
Y2
# Out:
# [7.812000000000001,
#  7.443,
#  7.895,
#  6.4110000000000005,
#  7.509,
#  6.737,
#  7.542,
#  5.5040000000000004,
#  7.3870000000000005,
#  6.308000000000001,
#  5.6000000000000005,
#  6.997,
#  6.446000000000001,
#  7.176,
#  6.407,
#  7.510000000000001,
#  6.882999999999999,
#  6.38,
#  7.227,
#  6.2669999999999995,
#  7.49,
#  6.859,
#  7.439,
#  6.97,
#  7.1610000000000005,
#  7.434000000000001,
#  7.674,
#  7.979,
#  7.147,
#  6.1240000000000006,
#  6.161,
#  6.032000000000001,
#  6.518,
#  7.41,
#  6.747,
#  7.286,
#  7.699,
#  7.075,
#  6.5649999999999995,
#  6.4270000000000005,
#  6.456,
#  7.154,
#  6.54,
#  5.564000000000001,
#  6.571,
#  6.564,
#  6.655,
#  7.025,
#  5.657,
#  6.617]

# %%
print(min(Y2),max(Y2))
# Out:
# 5.5040000000000004 7.979

# %%
Y3=[0]*50
k=0
for i in range(100,150):
    Y3[k]=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
    k+=1
Y3
# Out:
# [7.913,
#  6.819,
#  7.965,
#  7.361999999999999,
#  7.667999999999999,
#  8.460999999999999,
#  6.003,
#  8.088000000000001,
#  7.3420000000000005,
#  8.575000000000001,
#  7.508,
#  7.171000000000001,
#  7.675,
#  6.612,
#  6.974,
#  7.589,
#  7.486,
#  9.122000000000002,
#  8.375,
#  6.455000000000001,
#  7.971,
#  6.7379999999999995,
#  8.388,
#  6.956,
#  7.915,
#  8.138,
#  6.942,
#  7.074,
#  7.389,
#  7.888,
#  8.005,
#  9.066,
#  7.406,
#  7.050999999999999,
#  6.991999999999999,
#  8.350999999999999,
#  7.814000000000001,
#  7.510000000000001,
#  6.989999999999999,
#  7.753000000000001,
#  7.788000000000001,
#  7.673,
#  6.819,
#  8.001000000000001,
#  7.983,
#  7.549,
#  6.871,
#  7.406,
#  7.675000000000001,
#  7.058]

# %%
print(min(Y3),max(Y3))
# Out:
# 6.003 9.122000000000002

# %%
r=round(random.random(),3)
r
# Out:
# 0.051

# %%
W=[r for i in range(12)]
W
# Out:
# [0.051,
#  0.051,
#  0.051,
#  0.051,
#  0.051,
#  0.051,
#  0.051,
#  0.051,
#  0.051,
#  0.051,
#  0.051,
#  0.051]

# %%
Y1=[0]*50
for i in range(50):
    Y1[i]=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
Y1
# Out:
# [0.5201999999999999,
#  0.48450000000000004,
#  0.47940000000000005,
#  0.47939999999999994,
#  0.5202,
#  0.5813999999999999,
#  0.4946999999999999,
#  0.5151,
#  0.45389999999999997,
#  0.48960000000000004,
#  0.5508,
#  0.5099999999999999,
#  0.47429999999999994,
#  0.43349999999999994,
#  0.5711999999999999,
#  0.612,
#  0.5609999999999999,
#  0.5252999999999999,
#  0.5864999999999999,
#  0.5456999999999999,
#  0.5457,
#  0.5457,
#  0.47939999999999994,
#  0.5405999999999999,
#  0.5252999999999999,
#  0.4998,
#  0.5304,
#  0.5304,
#  0.5202,
#  0.49470000000000003,
#  0.4946999999999999,
#  0.5457,
#  0.5559,
#  0.5762999999999999,
#  0.48960000000000004,
#  0.4896,
#  0.5355,
#  0.48960000000000004,
#  0.45389999999999997,
#  0.5201999999999999,
#  0.5151,
#  0.4284,
#  0.46410000000000007,
#  0.5457,
#  0.5711999999999999,
#  0.48449999999999993,
#  0.5456999999999999,
#  0.47939999999999994,
#  0.5457,
#  0.5049]

# %%
print(min(Y1),max(Y1))
# Out:
# 0.4284 0.612

# %%
Y2=[0]*50
k=0
for i in range(50,100):
    Y2[k]=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
    k+=1
Y2
# Out:
# [0.8313,
#  0.7956000000000001,
#  0.8364,
#  0.6680999999999999,
#  0.7853999999999999,
#  0.7293000000000001,
#  0.8109,
#  0.5916,
#  0.7853999999999999,
#  0.6732,
#  0.5865,
#  0.7445999999999999,
#  0.6732,
#  0.7701,
#  0.6834,
#  0.7956000000000001,
#  0.7445999999999999,
#  0.6936,
#  0.7343999999999999,
#  0.6681,
#  0.8007,
#  0.7242,
#  0.7752,
#  0.7548,
#  0.7599,
#  0.7854,
#  0.8058,
#  0.8364,
#  0.7599,
#  0.6528,
#  0.6527999999999999,
#  0.6426,
#  0.6936,
#  0.7854,
#  0.7343999999999999,
#  0.7904999999999999,
#  0.8160000000000001,
#  0.7293000000000001,
#  0.714,
#  0.6783,
#  0.6987,
#  0.7700999999999999,
#  0.6936,
#  0.5916,
#  0.7038,
#  0.7191,
#  0.7191000000000001,
#  0.7496999999999999,
#  0.5967,
#  0.7089]

# %%
print(min(Y2),max(Y2))
# Out:
# 0.5865 0.8364

# %%
Y3=[0]*50
k=0
for i in range(100,150):
    Y3[k]=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
    k+=1
Y3
# Out:
# [0.9230999999999998,
#  0.7904999999999999,
#  0.9231,
#  0.8465999999999999,
#  0.8924999999999998,
#  0.9843,
#  0.6936,
#  0.9332999999999999,
#  0.8567999999999999,
#  0.9893999999999998,
#  0.8567999999999999,
#  0.8312999999999999,
#  0.8873999999999999,
#  0.7752,
#  0.8210999999999998,
#  0.8772,
#  0.8567999999999999,
#  1.0404,
#  0.9944999999999999,
#  0.7497,
#  0.9231,
#  0.7802999999999999,
#  0.9792,
#  0.8007,
#  0.9077999999999999,
#  0.9282,
#  0.7956,
#  0.8058,
#  0.8618999999999999,
#  0.8976,
#  0.9281999999999999,
#  1.0251000000000001,
#  0.8669999999999999,
#  0.8007,
#  0.8007,
#  0.9741,
#  0.9026999999999998,
#  0.8568,
#  0.7956,
#  0.8925,
#  0.9077999999999999,
#  0.8874,
#  0.7904999999999999,
#  0.9281999999999999,
#  0.9281999999999999,
#  0.8772,
#  0.8007,
#  0.8516999999999999,
#  0.8822999999999999,
#  0.8058]

# %%
print(min(Y3),max(Y3))
# Out:
# 0.6936 1.0404

# %%
W=[0.063 for i in range(12)]
W
# Out:
# [0.063,
#  0.063,
#  0.063,
#  0.063,
#  0.063,
#  0.063,
#  0.063,
#  0.063,
#  0.063,
#  0.063,
#  0.063,
#  0.063]

# %%
Y1=[0]*50
for i in range(50):
    Y1[i]=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
print(min(Y1),max(Y1))
# Out:
# 0.5292 0.7560000000000001

# %%
Y2=[0]*50
k=0
for i in range(50,100):
    Y2[k]=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
    k+=1
Y2
print(min(Y2),max(Y2))
# Out:
# 0.7244999999999999 1.0332000000000001

# %%
Y3=[0]*50
k=0
for i in range(100,150):
    Y3[k]=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
    k+=1
Y3
print(min(Y3),max(Y3))
# Out:
# 0.8568 1.2852000000000001

# %%
r=round(random.random(),3)
print(r)
W=[r for i in range(12)]
print(W)
# Out:
# 0.466
# [0.466, 0.466, 0.466, 0.466, 0.466, 0.466, 0.466, 0.466, 0.466, 0.466, 0.466, 0.466]

# %%
Y1=[0]*50
for i in range(50):
    Y1[i]=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
print(min(Y1),max(Y1))
# Out:
# 3.9144 5.592

# %%
Y2=[0]*50
k=0
for i in range(50,100):
    Y2[k]=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
    k+=1
Y2
print(min(Y2),max(Y2))
# Out:
# 5.359 7.642400000000001

# %%
Y3=[0]*50
k=0
for i in range(100,150):
    Y3[k]=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
    k+=1
Y3
print(min(Y3),max(Y3))
# Out:
# 6.337600000000001 9.506400000000001

# %%
W=[0.51]*12
W
# Out:
# [0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51, 0.51]

# %%
Y1=[0]*50
for i in range(50):
    Y1[i]=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
print(min(Y1),max(Y1))
# Out:
# 4.284 6.119999999999999

# %%
Y2=[0]*50
k=0
for i in range(50,100):
    Y2[k]=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
    k+=1
Y2
print(min(Y2),max(Y2))
# Out:
# 5.865 8.364

# %%
Y3=[0]*50
k=0
for i in range(100,150):
    Y3[k]=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
    k+=1
Y3
print(min(Y3),max(Y3))
# Out:
# 6.936 10.404

# %%
r=round(random.random(),2)
print(r)
W=[r for i in range(12)]
print(W)
# Out:
# 0.04
# [0.04, 0.04, 0.04, 0.04, 0.04, 0.04, 0.04, 0.04, 0.04, 0.04, 0.04, 0.04]

# %%
Y1=[0]*50
for i in range(50):
    Y1[i]=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
print(min(Y1),max(Y1))
# Out:
# 0.336 0.48000000000000004

# %%
Y2=[0]*50
k=0
for i in range(50,100):
    Y2[k]=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
    k+=1
Y2
print(min(Y2),max(Y2))
# Out:
# 0.46 0.6560000000000001

# %%
Y3=[0]*50
k=0
for i in range(100,150):
    Y3[k]=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
    k+=1
Y3
print(min(Y3),max(Y3))
# Out:
# 0.544 0.816

# %%
W=[]
for i in range(12):
    W.append(round(random.random(),2))
W
# Out:
# [0.4, 0.63, 0.59, 0.47, 0.09, 0.62, 0.99, 0.11, 0.83, 0.37, 0.8, 0.95]

# %%
Y1=[0]*50
for i in range(50):
    Y1[i]=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
print(min(Y1),max(Y1))
# Out:
# 4.255999999999999 5.981

# %%
Y2=[0]*50
k=0
for i in range(50,100):
    Y2[k]=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
    k+=1
Y2
print(min(Y2),max(Y2))
# Out:
# 4.466 6.401

# %%
Y3=[0]*50
k=0
for i in range(100,150):
    Y3[k]=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
    k+=1
Y3
print(min(Y3),max(Y3))
# Out:
# 9.791 14.55

# %%
W=[]
for i in range(12):
    W.append(round(random.random(),2))
W
# Out:
# [0.44, 0.22, 0.46, 0.22, 0.81, 0.78, 0.13, 0.34, 0.6, 0.14, 0.21, 0.91]

# %%
Y1=[0]*50
for i in range(50):
    Y1[i]=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
print(min(Y1),max(Y1))
# Out:
# 2.6969999999999996 3.727

# %%
Y2=[0]*50
k=0
for i in range(50,100):
    Y2[k]=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
    k+=1
Y2
print(min(Y2),max(Y2))
# Out:
# 4.12 6.024

# %%
Y3=[0]*50
k=0
for i in range(100,150):
    Y3[k]=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
    k+=1
Y3
print(min(Y3),max(Y3))
# Out:
# 8.451 12.528

# %%
W=[0.44, 0.22, 0.46, 0.22, 0.81, 0.78, 0.13, 0.34, 0.6, 0.14, 0.21, 0.91]
W
# Out:
# [0.44, 0.22, 0.46, 0.22, 0.81, 0.78, 0.13, 0.34, 0.6, 0.14, 0.21, 0.91]

# %%
Y=[0]*150
for i in range(150):
    Y[i]=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
print(min(Y[:50]),max(Y[:50]))
print(min(Y[50:100]),max(Y[50:100]))
print(min(Y[100:150]),max(Y[100:150]))
# Out:
# 2.6969999999999996 3.727
# 3.2350000000000003 4.591
# 3.5290000000000004 5.424

# %%
Y=[0]*150
for i in range(150):
    Y[i]=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
print(min(Y[:50]),max(Y[:50]))
print(min(Y[50:100]),max(Y[50:100]))
print(min(Y[100:150]),max(Y[100:150]))
# Out:
# 3.358 5.412
# 4.12 6.024
# 4.990000000000001 7.5120000000000005

# %%
Y=[0]*150
for i in range(150):
    Y[i]=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
print(min(Y[:50]),max(Y[:50]))
print(min(Y[50:100]),max(Y[50:100]))
print(min(Y[100:150]),max(Y[100:150]))
# Out:
# 4.917 7.3180000000000005
# 6.870000000000001 9.969000000000001
# 8.451 12.528

# %%
X.shape
# Out:
# (150, 5)

# %%
T=X[:,-1]

# %%
T
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
#        'versicolor', 'versicolor', 'versicolor', 'versicolor',
# ...

# %%
res=[]
for i in range(150):
    y1=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
    y2=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
    y3=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
    if((y1>=2.6969999999999996 and y1<=3.727)):
        res.append('setosa')
    if(y2>=4.12 and y2<=6.024):
        res.append('versicolor')
    if(y3>=8.451 and y3<=12.528):
        res.append('virginica')
res
# Out:
# ['setosa',
#  'versicolor',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'setosa',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
# ...

# %%
cnt=0
for i in range(150):
    if(res[i]==T[i]):
        cnt+=1
print(cnt)
# Out:
# 70

# %%
#W=[]
#for i in range(12):
 #   W.append(round(random.random(),5))
W=[0.55945,0.91284,0.20973,0.68228,0.5827,0.31477, 0.35105,0.02956,0.09045,0.7826,0.38955,0.52714]

# %%
Y1=[0]*150
for i in range(150):
    Y1[i]=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
print(min(Y1[:50]),max(Y1[:50]))
print(min(Y1[50:100]),max(Y1[50:100]))
print(min(Y1[100:150]),max(Y1[100:150]))
# Out:
# 4.777914 7.030512000000001
# 6.173085 8.880825
# 7.35715 10.974184

# %%
Y2=[0]*150
for i in range(150):
    Y2[i]=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
print(min(Y2[:50]),max(Y2[:50]))
print(min(Y2[50:100]),max(Y2[50:100]))
print(min(Y2[100:150]),max(Y2[100:150]))
# Out:
# 5.603282999999999 7.967228
# 6.2226099999999995 8.938822
# 6.724921000000001 10.393979999999999

# %%
Y3=[0]*150
for i in range(150):
    Y3[i]=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
print(min(Y3[:50]),max(Y3[:50]))
print(min(Y3[50:100]),max(Y3[50:100]))
print(min(Y3[100:150]),max(Y3[100:150]))
# Out:
# 1.9434829999999998 2.9269800000000004
# 2.5219050000000003 3.6978890000000004
# 3.1177650000000003 4.576770000000001

# %%
res=[]
for i in range(150):
    y1=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
    y2=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
    y3=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
    if((y1>=min(Y1[:50]) and y1<=max(Y1[:50]))):
        res.append('setosa')
    if(y2>=min(Y2[50:100]) and y2<=max(Y2[50:100])):
        res.append('versicolor')
    if(y3>=min(Y3[100:150]) and y3<=max(Y3[100:150])):
        res.append('virginica')
res
# Out:
# ['setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'setosa',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
#  'versicolor',
#  'setosa',
# ...

# %%
cnt=0
for i in range(150):
    if(res[i]==T[i]):
        cnt+=1
print(cnt)
# Out:
# 69

# %%
#W=[0]*12
#for i in range(12):
 #   W[i]=round(random.random(),2)
W=[0.65, 0.73, 0.89, 0.08, 0.19, 0.15, 0.69, 0.64, 0.22, 0.56, 0.63, 0.08]

# %%
Y1=[0]*150
for i in range(150):
    Y1[i]=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
print(min(Y1[:50]),max(Y1[:50]))
print(min(Y1[50:100]),max(Y1[50:100]))
print(min(Y1[100:150]),max(Y1[100:150]))
# Out:
# 3.85 5.3500000000000005
# 6.2010000000000005 8.997
# 7.442 11.262

# %%
Y2=[0]*150
for i in range(150):
    Y2[i]=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
print(min(Y2[:50]),max(Y2[:50]))
print(min(Y2[50:100]),max(Y2[50:100]))
print(min(Y2[100:150]),max(Y2[100:150]))
# Out:
# 4.475999999999999 6.209
# 6.7749999999999995 9.732000000000001
# 8.003 12.017

# %%
Y3=[0]*150
for i in range(150):
    Y3[i]=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
print(min(Y3[:50]),max(Y3[:50]))
print(min(Y3[50:100]),max(Y3[50:100]))
print(min(Y3[100:150]),max(Y3[100:150]))
# Out:
# 4.527 6.095000000000001
# 5.527000000000001 7.856000000000001
# 5.862000000000001 9.169

# %%
res=[]
for i in range(150):
    y1=X[i][0]*W[0]+X[i][1]*W[3]+X[i][2]*W[6]+X[i][3]*W[9]
    y2=X[i][0]*W[1]+X[i][1]*W[4]+X[i][2]*W[7]+X[i][3]*W[10]
    y3=X[i][0]*W[2]+X[i][1]*W[5]+X[i][2]*W[8]+X[i][3]*W[11]
    if((y1>=min(Y1[:50]) and y1<=max(Y1[:50]))):
        res.append('setosa')
    if(y2>=min(Y2[50:100]) and y2<=max(Y2[50:100])):
        res.append('versicolor')
    if(y3>=min(Y3[100:150]) and y3<=max(Y3[100:150])):
        res.append('virginica')
res
# Out:
# ['setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'virginica',
#  'setosa',
#  'virginica',
#  'setosa',
#  'setosa',
#  'setosa',
#  'virginica',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'versicolor',
#  'virginica',
#  'versicolor',
#  'virginica',
#  'versicolor',
#  'virginica',
#  'versicolor',
#  'virginica',
#  'versicolor',
#  'virginica',
#  'versicolor',
#  'virginica',
#  'versicolor',
#  'virginica',
#  'versicolor',
#  'versicolor',
#  'virginica',
#  'versicolor',
# ...

# %%
cnt=0
for i in range(150):
    if(res[i]==T[i]):
        cnt+=1
print(cnt)
# Out:
# 97
